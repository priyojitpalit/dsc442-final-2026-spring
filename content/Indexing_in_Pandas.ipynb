# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zynicide/wine-reviews")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 50.9M/50.9M [00:02<00:00, 26.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/zynicide/wine-reviews/versions/4

# %%
import pandas as pd
reviews = pd.read_csv(path + "/winemag-data-130k-v2.csv")

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
reviews['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
type(reviews)
# Out:
# pandas.core.frame.DataFrame

# %%
type(reviews['country'])
# Out:
# pandas.core.series.Series

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews['region_2']
# Out:
# 0                       NaN
# 1                       NaN
# 2         Willamette Valley
# 3                       NaN
# 4         Willamette Valley
#                 ...
# 129966                  NaN
# 129967         Oregon Other
# 129968                  NaN
# 129969                  NaN
# 129970                  NaN
# Name: region_2, Length: 129971, dtype: object

# %%
reviews['country'][0]
# Out:
# 'Italy'

# %%
reviews['country'][1]
# Out:
# 'Portugal'

# %%
reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
class  Student:
  def __init__(self, n, g): #the initialization function
    self.name = n #attribute
    self.gpa = g #attribute

  def introduce(self): # method
    print("Hi, my name is, ", self.name)

  def is_honors(self): # method
    if self.gpa >= 3.5:
      return True
    else:
      return False

  def alter_gpa(self, new_gpa):
    self.gpa = new_gpa

# %%
s = Student('Alice', 3.9)

# %%
s.name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_367/168450980.py in <cell line: 0>()
# ----> 1 s.name()
#
# TypeError: 'str' object is not callable

# %%
s.is_honors()
# Out:
# True

# %%
s.alter_gpa(3.0)

# %%
s.is_honors()
# Out:
# False

# %%
type(s)
# Out:
# __main__.Student

# %%
type(12)
# Out:
# int

# %%
s.name
# Out:
# 'Alice'

# %%
s.gpa
# Out:
# 3.9

# %%
s.introduce()
# Out:
# Hi, my name is,  Alice

# %%
s.is_honors()
# Out:
# True

# %%
s2 = Student('Bob', 3.8)

# %%
s.introduce()
# Out:
# Hi, my name is,  Alice

# %%
s2.introduce()
# Out:
# Hi, my name is,  Bob

# %%
data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex2 import *
print('Setup complete.')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_367/49180776.py in <cell line: 0>()
# ----> 1 from learntools.core import binder; binder.bind(globals())
#       2 from learntools.python.ex2 import *
#       3 print('Setup complete.')
#
# ModuleNotFoundError: No module named 'learntools'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
reviews['country'][1]

# %%
reviews.country()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_367/1072190274.py in <cell line: 0>()
# ----> 1 reviews.country()
#
# TypeError: 'Series' object is not callable

# %%
class  Student:
  def __init__(self, n, g): #the initialization function
    self.name = [1,2,3,4] #attribute
    self.gpa = g #attribute

  def introduce(self): # method
    print("Hi, my name is, ", self.name)

  def is_honors(self): # method
    if self.gpa >= 3.5:
      return True
    else:
      return False

  def alter_gpa(self, new_gpa):
    self.gpa = new_gpa

# %%
s3 = Student('Mike', 3.2)

# %%
s3.name
# Out:
# [1, 2, 3, 4]

# %%
#reviews.iloc[rows,columns]

# %%
reviews.iloc[1]
# Out:
# Unnamed: 0                                                               1
# country                                                           Portugal
# description              This is ripe and fruity, a wine that is smooth...
# designation                                                       Avidagos
# points                                                                  87
# price                                                                 15.0
# province                                                             Douro
# region_1                                                               NaN
# region_2                                                               NaN
# taster_name                                                     Roger Voss
# taster_twitter_handle                                           @vossroger
# title                        Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...

# %%
reviews.head(1)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
reviews.iloc[0:5]
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
reviews.iloc[0:5,2:4]
# Out:
#                                          description  \
# 0  Aromas include tropical fruit, broom, brimston...
# 1  This is ripe and fruity, a wine that is smooth...
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
#
#                           designation
# 0                        Vulkà Bianco
# 1                            Avidagos
# 2                                 NaN
# 3                Reserve Late Harvest
# 4  Vintner's Reserve Wild Child Block

# %%
reviews.iloc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %%
reviews.iloc[[1,3,18],[2,5]]
# Out:
#                                           description  price
# 1   This is ripe and fruity, a wine that is smooth...   15.0
# 3   Pineapple rind, lemon pith and orange blossom ...   13.0
# 18  Desiccated blackberry, leather, charred wood a...   28.0

# %%
reviews.iloc[129962:,:5]
# Out:
#         Unnamed: 0  country  \
# 129962      129962    Italy
# 129963      129963   Israel
# 129964      129964   France
# 129965      129965   France
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129962  Blackberry, cassis, grilled herb and toasted a...
# 129963  A bouquet of black cherry, tart cranberry and ...
# 129964  Initially quite muted, this wine slowly develo...
# 129965  While it's rich, this beautiful dry wine also ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points
# ...

# %%
reviews.iloc[-5:,]
# Out:
#         Unnamed: 0  country  \
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
# ...

# %%
reviews.loc[:,'description']
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
# 2         Tart and snappy, the flavors of lime flesh and...
# 3         Pineapple rind, lemon pith and orange blossom ...
# 4         Much like the regular bottling from 2012, this...
#                                 ...
# 129966    Notes of honeysuckle and cantaloupe sweeten th...
# 129967    Citation is given as much as a decade of bottl...
# 129968    Well-drained gravel soil gives this wine its c...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
reviews.head(2)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1      Avidagos      87   15.0              Douro      NaN      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos

# %%
new_reviews = reviews.set_index('country')

# %%
new_reviews.loc['Italy']
# Out:
#          Unnamed: 0                                        description  \
# country
# Italy             0  Aromas include tropical fruit, broom, brimston...
# Italy             6  Here's a bright, informal red that opens with ...
# Italy            13  This is dominated by oak and oak-driven aromas...
# Italy            22  Delicate aromas recall white flower and citrus...
# Italy            24  Aromas of prune, blackcurrant, toast and oak c...
# ...             ...                                                ...
# Italy        129929  This luminous sparkler has a sweet, fruit-forw...
# Italy        129943  A blend of Nero d'Avola and Syrah, this convey...
# Italy        129947  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# Italy        129961  Intense aromas of wild cherry, baking spice, t...
# Italy        129962  Blackberry, cassis, grilled herb and toasted a...
#
#                        designation  points  price           province  \
# country
# ...

# %%
data = {"country": ["Italy", "France", "Italy", "Spain"], "wine" : ["Chianti", "Bordeaux", "Barold", "Rioja"]}

# %%
review = pd.DataFrame(data)

# %%
review
# Out:
#   country      wine
# 0   Italy   Chianti
# 1  France  Bordeaux
# 2   Italy    Barold
# 3   Spain     Rioja

# %%
mask = [True, True, False, False]
review.loc[mask]
# Out:
#   country      wine
# 0   Italy   Chianti
# 1  France  Bordeaux

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
reviews.loc[:,['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#                taster_name taster_twitter_handle  points
# 0            Kerin O’Keefe          @kerinokeefe      87
# 1               Roger Voss            @vossroger      87
# 2             Paul Gregutt           @paulgwine       87
# 3       Alexander Peartree                   NaN      87
# 4             Paul Gregutt           @paulgwine       87
# ...                    ...                   ...     ...
# 129966  Anna Lee C. Iijima                   NaN      90
# 129967        Paul Gregutt           @paulgwine       90
# 129968          Roger Voss            @vossroger      90
# 129969          Roger Voss            @vossroger      90
# 129970          Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %%
reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 13              13   Italy  This is dominated by oak and oak-driven aromas...
# 22              22   Italy  Delicate aromas recall white flower and citrus...
# 24              24   Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...            ...     ...                                                ...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943      129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
# ...

# %%
data = reviews.loc[reviews.price.notnull()].copy()
data['value_score'] = data['points']/data['price']

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.price.notnull()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 129966     True
# 129967     True
# 129968     True
# 129969     True
# 129970     True
# Name: price, Length: 129971, dtype: bool

# %%
data
# Out:
#         Unnamed: 0   country  \
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# 5                5     Spain
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
data
# Out:
#         Unnamed: 0   country  \
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# 5                5     Spain
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#         Unnamed: 0 country                                        description  \
# 120            120   Italy  Slightly backward, particularly given the vint...
# 130            130   Italy  At the first it was quite muted and subdued, b...
# 133            133   Italy  Einaudi's wines have been improving lately, an...
# 135            135   Italy  The color is just beginning to show signs of b...
# 140            140   Italy  A big, fat, luscious wine with plenty of toast...
# ...            ...     ...                                                ...
# 129929      129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943      129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947      129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961      129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#         Unnamed: 0  country  \
# 0                0    Italy
# 6                6    Italy
# 13              13    Italy
# 22              22    Italy
# 24              24    Italy
# ...            ...      ...
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 6       Here's a bright, informal red that opens with ...
# 13      This is dominated by oak and oak-driven aromas...
# 22      Delicate aromas recall white flower and citrus...
# 24      Aromas of prune, blackcurrant, toast and oak c...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.loc[(reviews.country == 'Italy') | (reviews.country == 'France')]
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0   Italy  Aromas include tropical fruit, broom, brimston...
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 7                7  France  This dry and restrained wine offers spice in p...
# 9                9  France  This has great depth of flavor with its fresh ...
# 11              11  France  This is a dry wine, very spicy, with a tight, ...
# ...            ...     ...                                                ...
# 129964      129964  France  Initially quite muted, this wine slowly develo...
# 129965      129965  France  While it's rich, this beautiful dry wine also ...
# 129968      129968  France  Well-drained gravel soil gives this wine its c...
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
reviews.loc[reviews.price.notnull() & ((reviews.country == 'Italy') | (reviews.country == 'France'))]
# Out:
#         Unnamed: 0 country                                        description  \
# 6                6   Italy  Here's a bright, informal red that opens with ...
# 7                7  France  This dry and restrained wine offers spice in p...
# 9                9  France  This has great depth of flavor with its fresh ...
# 11              11  France  This is a dry wine, very spicy, with a tight, ...
# 22              22   Italy  Delicate aromas recall white flower and citrus...
# ...            ...     ...                                                ...
# 129962      129962   Italy  Blackberry, cassis, grilled herb and toasted a...
# 129965      129965  France  While it's rich, this beautiful dry wine also ...
# 129968      129968  France  Well-drained gravel soil gives this wine its c...
# 129969      129969  France  A dry style of Pinot Gris, this is crisp with ...
# 129970      129970  France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
reviews.loc[reviews.price.isnull()]
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 13              13     Italy
# 30              30    France
# 31              31     Italy
# 32              32     Italy
# ...            ...       ...
# 129844      129844     Italy
# 129860      129860  Portugal
# 129863      129863  Portugal
# 129893      129893     Italy
# 129964      129964    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 13      This is dominated by oak and oak-driven aromas...
# 30      Red cherry fruit comes laced with light tannin...
# 31      Merlot and Nero d'Avola form the base for this...
# 32      Part of the extended Calanìca series, this Gri...
# ...                                                   ...
# 129844  Doga delle Clavule is a neutral, mineral-drive...
# 129860  This rich wine has a firm structure as well as...
# 129863  This mature wine that has 50% Touriga Nacional...
# ...

# %%
reviews['critic'] = "everyone"

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.loc[reviews.price > 60, 'critic'] = 'no one'

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.points > 60
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 129966    True
# 129967    True
# 129968    True
# 129969    True
# 129970    True
# Name: points, Length: 129971, dtype: bool

# %%
not_null_priced_reviews = reviews.loc[reviews.price.notnull()]

# %%
not_null_priced_reviews['new column']=not_null_priced_reviews['price']/not_null_priced_reviews['points']
# Out:
# /tmp/ipykernel_407/502523860.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_null_priced_reviews['new column']=not_null_priced_reviews['price']/not_null_priced_reviews['points']

# %%
not_null_priced_reviews
# Out:
#         Unnamed: 0   country  \
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# 5                5     Spain
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# 5       Blackberry and raspberry aromas show a typical...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...
