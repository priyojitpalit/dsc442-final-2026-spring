# %%
import pandas as pd

# %%
melbourne_file_path = 'https://raw.githubusercontent.com/dipalira/Melbourne-Housing-Data-Kaggle/refs/heads/master/Data/Melbourne_housing_FULL.csv'

# %%
melbourne_data = pd.read_csv(melbourne_file_path)

# %%
melbourne_data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
melbourne_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
melbourne_data = melbourne_data.dropna(axis = 0)

# %%
melbourne_data
# Out:
#            Suburb           Address  Rooms Type      Price Method  SellerG  \
# 2      Abbotsford   25 Bloomburg St      2    h  1035000.0      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1465000.0     SP   Biggin
# 6      Abbotsford       55a Park St      4    h  1600000.0     VB   Nelson
# 11     Abbotsford      124 Yarra St      3    h  1876000.0      S   Nelson
# 14     Abbotsford     98 Charles St      2    h  1636000.0      S   Nelson
# ...           ...               ...    ...  ...        ...    ...      ...
# 34847     Wollert   27 Birchmore Rd      3    h   500000.0     PI      Ray
# 34849     Wollert   35 Kingscote Wy      3    h   570000.0     SP       RW
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t   705000.0      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI       RW
#
# ...

# %%
melbourne_data.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  8887.000000  8.887000e+03  8887.000000  8887.000000  8887.000000
# mean      3.098909  1.092902e+06    11.199887  3111.662653     3.078204
# std       0.963786  6.793819e+05     6.813402   112.614268     0.966269
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.410000e+05     6.400000  3044.000000     2.000000
# 50%       3.000000  9.000000e+05    10.200000  3084.000000     3.000000
# 75%       4.000000  1.345000e+06    13.900000  3150.000000     4.000000
# max      12.000000  9.000000e+06    47.400000  3977.000000    12.000000
#
#           Bathroom          Car      Landsize  BuildingArea    YearBuilt  \
# count  8887.000000  8887.000000   8887.000000   8887.000000  8887.000000
# mean      1.646450     1.692247    523.480365    149.309477  1965.753348
# std       0.721611     0.975464   1061.324228     87.925580    37.040876
# ...

# %% [markdown]
# # Prediction Target (y)

# %%
y = melbourne_data.Price

# %%
y
# Out:
# 2        1035000.0
# 4        1465000.0
# 6        1600000.0
# 11       1876000.0
# 14       1636000.0
#            ...
# 34847     500000.0
# 34849     570000.0
# 34853     888000.0
# 34854     705000.0
# 34856    1020000.0
# Name: Price, Length: 8887, dtype: float64

# %% [markdown]
# # Choose Features (X)

# %%
melbourne_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
melbourne_features = ['Rooms','Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
X = melbourne_data[melbourne_features]

# %%
X
# Out:
#        Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 2          2       1.0     156.0  -37.80790   144.99340
# 4          3       2.0     134.0  -37.80930   144.99440
# 6          4       1.0     120.0  -37.80720   144.99410
# 11         3       2.0     245.0  -37.80240   144.99930
# 14         2       1.0     256.0  -37.80600   144.99540
# ...      ...       ...       ...        ...         ...
# 34847      3       2.0     383.0  -37.61940   145.03951
# 34849      3       2.0     404.0  -37.61031   145.03393
# 34853      2       2.0      98.0  -37.81551   144.88826
# 34854      2       1.0     220.0  -37.82286   144.87856
# 34856      2       1.0     250.0  -37.81810   144.89351
#
# [8887 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeRegressor
melbourne_model = DecisionTreeRegressor(random_state = 1)
#Fit the model to our current data
melbourne_model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print(X.head())
# Out:
#     Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 2       2       1.0     156.0   -37.8079    144.9934
# 4       3       2.0     134.0   -37.8093    144.9944
# 6       4       1.0     120.0   -37.8072    144.9941
# 11      3       2.0     245.0   -37.8024    144.9993
# 14      2       1.0     256.0   -37.8060    144.9954

# %%
melbourne_model.predict(X.head())
# Out:
# array([1035000., 1465000., 1600000., 1876000., 1636000.])

# %%
# d = {'Rooms': [15], 'Bathroom':[10],  'Landsize': [1000],  'Lattitude': [-37.8079],  'Longtitude': [144.9934]}
# df = pd.DataFrame(d)

# %%
# melbourne_model.predict(df)

# %% [markdown]
# # Model Validation
# Mean Absolute Error (MAE) metric

# %%
from sklearn.metrics import mean_absolute_error
predicted_home_prices = melbourne_model.predict(X)
mean_absolute_error(y,predicted_home_prices)
# Out:
# 897.2844229398746

# %%
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(X,y, random_state= 1)

# %%
a, b, c = (1, 3, 4)
print(b)
# Out:
# 3

# %%
melbourne_model = DecisionTreeRegressor()
melbourne_model.fit(train_X, train_y)
# Out:
# DecisionTreeRegressor()

# %%
incorrect_prediction = melbourne_model.predict(train_X)
print(mean_absolute_error(train_y, incorrect_prediction))
# Out:
# 389.6224056014003

# %%
train_X
# Out:
#        Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 27414      2       1.0     670.0  -37.89490   144.66260
# 4075       4       2.0       0.0  -37.74650   144.91000
# 7886       1       1.0       0.0  -37.84360   144.94400
# 10252      1       1.0       0.0  -37.76200   144.99600
# 31000      4       1.0     583.0  -37.71357   144.57512
# ...      ...       ...       ...        ...         ...
# 13554      4       3.0     697.0  -37.70100   144.99930
# 30441      3       1.0     593.0  -37.94406   145.03219
# 15315      3       2.0     600.0  -37.57686   144.71023
# 9873       5       2.0     661.0  -37.76510   144.82410
# 8273       3       1.0     495.0  -37.75210   145.01140
#
# [6665 rows x 5 columns]

# %%
incorrect_prediction
# Out:
# array([ 547000., 1170000.,  470000., ...,  410000.,  605000.,  890000.])

# %%
val_prediction = melbourne_model.predict(val_X)

# %%
print(mean_absolute_error(val_y, val_prediction))
# Out:
# 252417.40774077407

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
  model = DecisionTreeRegressor(max_leaf_nodes = max_leaf_nodes, random_state = 0)
  model.fit(train_X, train_y)
  preds_val = model.predict(val_X)
  mae = mean_absolute_error(val_y, preds_val)
  return mae
for max_leaf_nodes in [2, 10, 20, 30, 40, 50, 100, 200, 250, 300, 350, 400]:
  my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
  print(f"Maximum leaf nodes = {max_leaf_nodes}, Error = {my_mae}")
# Out:
# Maximum leaf nodes = 2, Error = 434051.3222339987
# Maximum leaf nodes = 10, Error = 320323.11545654776
# Maximum leaf nodes = 20, Error = 295217.9557555797
# Maximum leaf nodes = 30, Error = 281668.50305117166
# Maximum leaf nodes = 40, Error = 268140.13802793896
# Maximum leaf nodes = 50, Error = 269635.77944333066
# Maximum leaf nodes = 100, Error = 251472.71131411262
# Maximum leaf nodes = 200, Error = 237595.34453951268
# Maximum leaf nodes = 250, Error = 234448.9314130733
# Maximum leaf nodes = 300, Error = 235189.23487943437
# Maximum leaf nodes = 350, Error = 234224.26692657016
# Maximum leaf nodes = 400, Error = 234074.74251054192

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import median_absolute_error

forest_model  = RandomForestRegressor(n_estimators = 50, random_state = 1)
forest_model.fit(train_X, train_y)
melb_preds = forest_model.predict(val_X)
print(mean_absolute_error(val_y, melb_preds))
# Out:
# 187915.7592919292

# %%
melbourne_data.Suburb.unique()
# Out:
# array(['Abbotsford', 'Airport West', 'Albert Park', 'Alphington',
#        'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton',
#        'Ashwood', 'Avondale Heights', 'Balaclava', 'Balwyn',
#        'Balwyn North', 'Bentleigh', 'Bentleigh East', 'Box Hill',
#        'Braybrook', 'Brighton', 'Brighton East', 'Brunswick',
#        'Brunswick West', 'Bulleen', 'Burwood', 'Camberwell', 'Canterbury',
#        'Carlton North', 'Carnegie', 'Caulfield', 'Caulfield North',
#        'Caulfield South', 'Chadstone', 'Clifton Hill', 'Coburg',
#        'Coburg North', 'Collingwood', 'Doncaster', 'Eaglemont',
#        'Elsternwick', 'Elwood', 'Essendon', 'Essendon North', 'Fairfield',
#        'Fitzroy', 'Fitzroy North', 'Flemington', 'Footscray', 'Glen Iris',
#        'Glenroy', 'Gowanbrae', 'Hadfield', 'Hampton', 'Hampton East',
#        'Hawthorn', 'Heidelberg Heights', 'Heidelberg West', 'Hughesdale',
#        'Ivanhoe', 'Kealba', 'Keilor East', 'Kensington', 'Kew',
# ...

# %%
data = pd.read_csv(melbourne_file_path)
data = data.dropna(subset = ['Price'])
