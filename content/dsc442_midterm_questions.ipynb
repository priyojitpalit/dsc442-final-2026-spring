# %% [markdown]
# # DSC 442 Midterm — Data Analysis Coding Test
# **Time:** 75 minutes
#
# Run the notebook from top to bottom.
#
# **Rules:** Work independently. No external websites. No generative AI tools.
#
# After the setup step, you will work with a **list of dictionaries** named `countries`.
# Each dictionary represents one country from the World Happiness dataset.
#
# Write code only in cells marked **Your Code Here** and store answers in the specified variables.

# %% [markdown]
# ## Dataset Setup (do not edit)
# The file `2015.csv` contains the World Happiness dataset.
# This cell loads the dataset and converts it into a **list of dictionaries**.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('data/2015.csv')

# Keep only the columns needed for the test
df = df[[
    'Country',
    'Region',
    'Happiness Score',
    'Economy (GDP per Capita)',
    'Family',
    'Health (Life Expectancy)',
    'Freedom',
    'Trust (Government Corruption)',
    'Generosity'
]]

# Convert dataframe to list of dictionaries
countries = df.to_dict('records')

# Preview
countries[:2]

# %% [markdown]
# ## Example Usage (not graded)
# Run the next cell to see what the data looks like.

# %%
for c in countries[:5]:
    print(c['Country'], '|', c['Region'], '|', c['Happiness Score'])

# %% [markdown]
# ## Question 1
# Compute the **total number of countries**.
#
# Store the result in:
# `Q1_total_countries`

# %%
# Your Code Here
Q1_total_countries = None

Q1_total_countries

# %% [markdown]
# ## Question 2
# Compute the **average happiness score** across all countries.
#
# Store the result in:
# `Q2_avg_happiness`

# %%
# Your Code Here
Q2_avg_happiness = None

Q2_avg_happiness

# %% [markdown]
# ## Question 3
# Find the **country with the highest happiness score**.
#
# Store the result in:
# `Q3_happiest_country`

# %%
# Your Code Here
Q3_happiest_country = None

Q3_happiest_country

# %% [markdown]
# ## Question 4
# Compute the **average happiness score for each region**.
#
# Store the result in a dictionary:
# `Q4_region_avg`
#
# Example structure:
# `{'Western Europe': 6.8, 'North America': 7.2, ...}`

# %%
# Your Code Here
Q4_region_avg = None

Q4_region_avg

# %% [markdown]
# ## Question 5
# Determine **which region has the highest average happiness score**.
#
# Store the region name in:
# `Q5_happiest_region`

# %%
# Your Code Here
Q5_happiest_region = None

Q5_happiest_region

# %% [markdown]
# ## Question 6
# For the region stored in `Q5_happiest_region`, compute the **average GDP per capita score**.
#
# The column name is `'Economy (GDP per Capita)'`.
#
# Store the result in:
# `Q6_avg_gdp_happiest_region`

# %%
# Your Code Here
Q6_avg_gdp_happiest_region = None

Q6_avg_gdp_happiest_region

# %% [markdown]
# ## Question 7
# Create a **scorecard** for the happiest region.
#
# For all countries in the happiest region, compute the average of:
#
# - Economy (GDP per Capita)
# - Family
# - Health (Life Expectancy)
# - Freedom
# - Trust (Government Corruption)
# - Generosity
#
# Store the result in a dictionary:
# `Q7_scorecard`

# %%
# Your Code Here
Q7_scorecard = None

Q7_scorecard

# %% [markdown]
# ## Final Check (do not edit)
# Run this cell before submitting.

# %%
answers = {
    'Q1_total_countries': Q1_total_countries,
    'Q2_avg_happiness': Q2_avg_happiness,
    'Q3_happiest_country': Q3_happiest_country,
    'Q4_region_avg_type': type(Q4_region_avg),
    'Q5_happiest_region': Q5_happiest_region,
    'Q6_avg_gdp_happiest_region': Q6_avg_gdp_happiest_region,
    'Q7_scorecard_type': type(Q7_scorecard)
}

answers
